# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import matplotlib.pyplot as plt
import numpy as np
import time

# Device configuration (Use GPU if available)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Hyperparameters
BATCH_SIZE = 64
EPOCHS = 5
LEARNING_RATE = 0.001
# Out:
# Using device: cuda

# %% [markdown]
# **DATASET LOADING**

# %%
# Image transforms (Augmentation + Normalization)
transform_train = transforms.Compose([
    transforms.Resize((32, 32)), # CIFAR is 32x32, CatsDogs needs resize to 64x64 or 128x128
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_test = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load CIFAR-10
print("Loading CIFAR-10 Dataset...")
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Loading CIFAR-10 Dataset...
# 100%|██████████| 170M/170M [00:03<00:00, 43.2MB/s]

# %% [markdown]
# **DEFINING THE CONFIGURABLE CNN ARCHITECTURE**

# %%
class ConfigurableCNN(nn.Module):
    def __init__(self, activation_fn_name='relu', num_classes=10):
        super(ConfigurableCNN, self).__init__()

        # Select Activation Function
        if activation_fn_name == 'relu':
            self.activation = nn.ReLU()
        elif activation_fn_name == 'tanh':
            self.activation = nn.Tanh()
        elif activation_fn_name == 'leaky_relu':
            self.activation = nn.LeakyReLU(0.01)


        # Layer 1
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.pool = nn.MaxPool2d(2, 2)

        # Layer 2
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)

        # Layer 3
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)

        # Fully Connected Layers
        # 32x32 image -> pool -> 16x16 -> pool -> 8x8 -> pool -> 4x4
        self.flatten_dim = 128 * 4 * 4

        self.fc1 = nn.Linear(self.flatten_dim, 512)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        # Block 1
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.activation(x)
        x = self.pool(x)

        # Block 2
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.activation(x)
        x = self.pool(x)

        # Block 3
        x = self.conv3(x)
        x = self.bn3(x)
        x = self.activation(x)
        x = self.pool(x)

        # Classifier
        x = x.view(-1, self.flatten_dim)
        x = self.fc1(x)
        x = self.activation(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# **INITIALIZATION TECHNIQUES**

# %%
def apply_weight_init(model, init_type='random'):
    def init_weights(m):
        if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
            if init_type == 'xavier':
                nn.init.xavier_uniform_(m.weight)
            elif init_type == 'kaiming':
                nn.init.kaiming_uniform_(m.weight, nonlinearity='relu')
            elif init_type == 'random':
                nn.init.normal_(m.weight, mean=0.0, std=0.02) # Simple random normal

            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

    model.apply(init_weights)

# %% [markdown]
# **TRAINING UTILITY FUNCTION**

# %%
def train_model(model, train_loader, criterion, optimizer, epochs=5):
    model.train()
    history = {'loss': [], 'acc': []}

    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_acc = 100 * correct / total
        epoch_loss = running_loss / len(train_loader)
        history['loss'].append(epoch_loss)
        history['acc'].append(epoch_acc)

        print(f"Epoch [{epoch+1}/{epochs}], Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.2f}%")

    return history

# %% [markdown]
# **EVALUATION UTILITY FUNCTION**

# %%
def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return acc

# %% [markdown]
# **EXPERIMENT CONFIGURATIONS (AROUND 27 DIFFERENT CONFIG)**

# %%
# Experiment Configurations
activations = ['relu', 'tanh', 'leaky_relu']
initializations = ['xavier', 'kaiming', 'random']
optimizers_list = ['sgd', 'adam', 'rmsprop']

results = []
best_acc = 0
best_config = {}
best_model_state = None

print("Starting Experiments...")

# Iterate through all combinations
for act in activations:
    for init in initializations:
        for opt_name in optimizers_list:
            print(f"\n--- Config: Act={act}, Init={init}, Optim={opt_name} ---")

            # 1. Initialize Model
            model = ConfigurableCNN(activation_fn_name=act, num_classes=10).to(device)

            # 2. Apply Weight Init
            apply_weight_init(model, init_type=init)

            # 3. Setup Optimizer
            criterion = nn.CrossEntropyLoss()
            if opt_name == 'sgd':
                optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9)
            elif opt_name == 'adam':
                optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
            elif opt_name == 'rmsprop':
                optimizer = optim.RMSprop(model.parameters(), lr=LEARNING_RATE)

            # 4. Train
            # Using 2 epochs to speed up demonstration (Use 5+ for real lab)
            train_hist = train_model(model, train_loader, criterion, optimizer, epochs=30)

            # 5. Evaluate
            test_acc = evaluate_model(model, test_loader)
            print(f"Test Accuracy: {test_acc:.2f}%")

            # Store results
            results.append({
                'config': f"{act}_{init}_{opt_name}",
                'acc': test_acc
            })

            # Check for best model
            if test_acc > best_acc:
                best_acc = test_acc
                best_config = {'act': act, 'init': init, 'opt': opt_name}
                best_model_state = model.state_dict()
                torch.save(model.state_dict(), "best_custom_cnn.pth")

print(f"\nBest Custom Configuration: {best_config} with Acc: {best_acc:.2f}%")
# Out:
# Starting Experiments...
#
# --- Config: Act=relu, Init=xavier, Optim=sgd ---
# Epoch [1/30], Loss: 1.6189, Acc: 42.33%
# Epoch [2/30], Loss: 1.2687, Acc: 54.51%
# Epoch [3/30], Loss: 1.1239, Acc: 60.00%
# Epoch [4/30], Loss: 1.0322, Acc: 63.08%
# Epoch [5/30], Loss: 0.9682, Acc: 65.90%
# Epoch [6/30], Loss: 0.9183, Acc: 67.50%
# Epoch [7/30], Loss: 0.8719, Acc: 69.58%
# Epoch [8/30], Loss: 0.8316, Acc: 70.78%
# Epoch [9/30], Loss: 0.8014, Acc: 71.97%
# Epoch [10/30], Loss: 0.7728, Acc: 72.93%
# Epoch [11/30], Loss: 0.7492, Acc: 73.80%
# Epoch [12/30], Loss: 0.7247, Acc: 74.73%
# Epoch [13/30], Loss: 0.7055, Acc: 75.21%
# Epoch [14/30], Loss: 0.6824, Acc: 76.04%
# Epoch [15/30], Loss: 0.6671, Acc: 76.72%
# Epoch [16/30], Loss: 0.6464, Acc: 77.51%
# Epoch [17/30], Loss: 0.6309, Acc: 77.76%
# Epoch [18/30], Loss: 0.6147, Acc: 78.57%
# Epoch [19/30], Loss: 0.6007, Acc: 78.90%
# Epoch [20/30], Loss: 0.5835, Acc: 79.47%
# Epoch [21/30], Loss: 0.5729, Acc: 80.07%
# Epoch [22/30], Loss: 0.5571, Acc: 80.57%
# Epoch [23/30], Loss: 0.5470, Acc: 80.90%
# Epoch [24/30], Loss: 0.5385, Acc: 81.08%
# Epoch [25/30], Loss: 0.5238, Acc: 81.50%
# Epoch [26/30], Loss: 0.5140, Acc: 81.83%
# Epoch [27/30], Loss: 0.5030, Acc: 82.38%
# Epoch [28/30], Loss: 0.4908, Acc: 82.74%
# Epoch [29/30], Loss: 0.4846, Acc: 83.00%
# Epoch [30/30], Loss: 0.4709, Acc: 83.34%
# Test Accuracy: 78.91%
#
# --- Config: Act=relu, Init=xavier, Optim=adam ---
# Epoch [1/30], Loss: 1.5558, Acc: 44.44%
# Epoch [2/30], Loss: 1.1613, Acc: 58.27%
# Epoch [3/30], Loss: 1.0060, Acc: 64.73%
# Epoch [4/30], Loss: 0.9235, Acc: 67.72%
# Epoch [5/30], Loss: 0.8510, Acc: 70.41%
# Epoch [6/30], Loss: 0.7908, Acc: 72.71%
# Epoch [7/30], Loss: 0.7414, Acc: 74.45%
# Epoch [8/30], Loss: 0.6977, Acc: 76.16%
# Epoch [9/30], Loss: 0.6639, Acc: 77.15%
# Epoch [10/30], Loss: 0.6307, Acc: 78.25%
# Epoch [11/30], Loss: 0.6053, Acc: 79.30%
# Epoch [12/30], Loss: 0.5742, Acc: 80.18%
# Epoch [13/30], Loss: 0.5526, Acc: 80.96%
# Epoch [14/30], Loss: 0.5215, Acc: 82.30%
# Epoch [15/30], Loss: 0.4984, Acc: 82.68%
# Epoch [16/30], Loss: 0.4834, Acc: 83.31%
# Epoch [17/30], Loss: 0.4631, Acc: 83.97%
# Epoch [18/30], Loss: 0.4517, Acc: 84.49%
# Epoch [19/30], Loss: 0.4263, Acc: 85.29%
# Epoch [20/30], Loss: 0.4140, Acc: 85.84%
# Epoch [21/30], Loss: 0.3937, Acc: 86.47%
# Epoch [22/30], Loss: 0.3846, Acc: 86.66%
# Epoch [23/30], Loss: 0.3694, Acc: 87.28%
# Epoch [24/30], Loss: 0.3559, Acc: 87.64%
# Epoch [25/30], Loss: 0.3449, Acc: 88.03%
# Epoch [26/30], Loss: 0.3381, Acc: 88.24%
# Epoch [27/30], Loss: 0.3204, Acc: 88.83%
# Epoch [28/30], Loss: 0.3121, Acc: 89.12%
# Epoch [29/30], Loss: 0.3056, Acc: 89.43%
# Epoch [30/30], Loss: 0.2879, Acc: 90.09%
# Test Accuracy: 81.65%
#
# --- Config: Act=relu, Init=xavier, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.8311, Acc: 40.93%
# Epoch [2/30], Loss: 1.2160, Acc: 56.25%
# Epoch [3/30], Loss: 1.0431, Acc: 63.29%
# Epoch [4/30], Loss: 0.9366, Acc: 67.22%
# Epoch [5/30], Loss: 0.8611, Acc: 70.23%
# Epoch [6/30], Loss: 0.8047, Acc: 71.94%
# Epoch [7/30], Loss: 0.7567, Acc: 73.91%
# Epoch [8/30], Loss: 0.7102, Acc: 75.57%
# Epoch [9/30], Loss: 0.6651, Acc: 76.97%
# Epoch [10/30], Loss: 0.6392, Acc: 78.17%
# Epoch [11/30], Loss: 0.6039, Acc: 79.33%
# Epoch [12/30], Loss: 0.5751, Acc: 79.89%
# Epoch [13/30], Loss: 0.5498, Acc: 81.08%
# Epoch [14/30], Loss: 0.5210, Acc: 82.08%
# Epoch [15/30], Loss: 0.4999, Acc: 82.85%
# Epoch [16/30], Loss: 0.4757, Acc: 83.54%
# Epoch [17/30], Loss: 0.4527, Acc: 84.19%
# Epoch [18/30], Loss: 0.4389, Acc: 84.84%
# Epoch [19/30], Loss: 0.4187, Acc: 85.43%
# Epoch [20/30], Loss: 0.3999, Acc: 86.01%
# Epoch [21/30], Loss: 0.3865, Acc: 86.52%
# Epoch [22/30], Loss: 0.3703, Acc: 87.20%
# Epoch [23/30], Loss: 0.3562, Acc: 87.52%
# Epoch [24/30], Loss: 0.3437, Acc: 87.92%
# Epoch [25/30], Loss: 0.3274, Acc: 88.41%
# Epoch [26/30], Loss: 0.3205, Acc: 88.79%
# Epoch [27/30], Loss: 0.3052, Acc: 89.31%
# Epoch [28/30], Loss: 0.2927, Acc: 89.66%
# Epoch [29/30], Loss: 0.2860, Acc: 89.99%
# Epoch [30/30], Loss: 0.2796, Acc: 90.30%
# Test Accuracy: 75.96%
#
# --- Config: Act=relu, Init=kaiming, Optim=sgd ---
# Epoch [1/30], Loss: 1.6729, Acc: 40.54%
# Epoch [2/30], Loss: 1.3543, Acc: 51.17%
# Epoch [3/30], Loss: 1.2176, Acc: 56.22%
# Epoch [4/30], Loss: 1.1255, Acc: 59.93%
# Epoch [5/30], Loss: 1.0603, Acc: 62.30%
# Epoch [6/30], Loss: 1.0011, Acc: 64.62%
# Epoch [7/30], Loss: 0.9596, Acc: 66.11%
# Epoch [8/30], Loss: 0.9242, Acc: 67.03%
# Epoch [9/30], Loss: 0.8916, Acc: 68.40%
# Epoch [10/30], Loss: 0.8632, Acc: 69.52%
# Epoch [11/30], Loss: 0.8360, Acc: 70.56%
# Epoch [12/30], Loss: 0.8111, Acc: 71.39%
# Epoch [13/30], Loss: 0.7913, Acc: 72.24%
# Epoch [14/30], Loss: 0.7713, Acc: 72.90%
# Epoch [15/30], Loss: 0.7488, Acc: 73.43%
# Epoch [16/30], Loss: 0.7319, Acc: 74.33%
# Epoch [17/30], Loss: 0.7190, Acc: 74.81%
# Epoch [18/30], Loss: 0.7032, Acc: 75.31%
# Epoch [19/30], Loss: 0.6841, Acc: 76.10%
# Epoch [20/30], Loss: 0.6743, Acc: 76.42%
# Epoch [21/30], Loss: 0.6597, Acc: 76.89%
# Epoch [22/30], Loss: 0.6458, Acc: 77.36%
# Epoch [23/30], Loss: 0.6354, Acc: 77.58%
# Epoch [24/30], Loss: 0.6186, Acc: 77.99%
# Epoch [25/30], Loss: 0.6077, Acc: 78.57%
# Epoch [26/30], Loss: 0.5961, Acc: 79.11%
# Epoch [27/30], Loss: 0.5892, Acc: 79.19%
# Epoch [28/30], Loss: 0.5785, Acc: 79.58%
# Epoch [29/30], Loss: 0.5673, Acc: 80.17%
# Epoch [30/30], Loss: 0.5565, Acc: 80.46%
# Test Accuracy: 77.35%
#
# --- Config: Act=relu, Init=kaiming, Optim=adam ---
# Epoch [1/30], Loss: 1.5488, Acc: 44.14%
# Epoch [2/30], Loss: 1.1769, Acc: 58.00%
# Epoch [3/30], Loss: 1.0385, Acc: 63.48%
# Epoch [4/30], Loss: 0.9515, Acc: 66.43%
# Epoch [5/30], Loss: 0.8808, Acc: 69.44%
# Epoch [6/30], Loss: 0.8227, Acc: 71.42%
# Epoch [7/30], Loss: 0.7759, Acc: 72.99%
# Epoch [8/30], Loss: 0.7379, Acc: 74.56%
# Epoch [9/30], Loss: 0.6976, Acc: 76.07%
# Epoch [10/30], Loss: 0.6652, Acc: 77.15%
# Epoch [11/30], Loss: 0.6345, Acc: 78.08%
# Epoch [12/30], Loss: 0.6083, Acc: 78.84%
# Epoch [13/30], Loss: 0.5811, Acc: 79.99%
# Epoch [14/30], Loss: 0.5597, Acc: 80.85%
# Epoch [15/30], Loss: 0.5387, Acc: 81.42%
# Epoch [16/30], Loss: 0.5153, Acc: 82.18%
# Epoch [17/30], Loss: 0.4906, Acc: 83.06%
# Epoch [18/30], Loss: 0.4783, Acc: 83.48%
# Epoch [19/30], Loss: 0.4636, Acc: 84.14%
# Epoch [20/30], Loss: 0.4420, Acc: 84.70%
# Epoch [21/30], Loss: 0.4276, Acc: 85.31%
# Epoch [22/30], Loss: 0.4117, Acc: 85.65%
# Epoch [23/30], Loss: 0.3955, Acc: 86.25%
# Epoch [24/30], Loss: 0.3833, Acc: 86.55%
# Epoch [25/30], Loss: 0.3708, Acc: 87.15%
# Epoch [26/30], Loss: 0.3654, Acc: 87.26%
# Epoch [27/30], Loss: 0.3512, Acc: 87.76%
# Epoch [28/30], Loss: 0.3344, Acc: 88.39%
# Epoch [29/30], Loss: 0.3278, Acc: 88.77%
# Epoch [30/30], Loss: 0.3164, Acc: 89.00%
# Test Accuracy: 81.25%
#
# --- Config: Act=relu, Init=kaiming, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.8144, Acc: 41.53%
# Epoch [2/30], Loss: 1.2092, Acc: 56.76%
# Epoch [3/30], Loss: 1.0427, Acc: 63.17%
# Epoch [4/30], Loss: 0.9455, Acc: 66.87%
# Epoch [5/30], Loss: 0.8697, Acc: 69.74%
# Epoch [6/30], Loss: 0.8115, Acc: 72.18%
# Epoch [7/30], Loss: 0.7591, Acc: 73.78%
# Epoch [8/30], Loss: 0.7088, Acc: 75.36%
# Epoch [9/30], Loss: 0.6762, Acc: 76.80%
# Epoch [10/30], Loss: 0.6375, Acc: 78.06%
# Epoch [11/30], Loss: 0.6059, Acc: 78.97%
# Epoch [12/30], Loss: 0.5735, Acc: 80.27%
# Epoch [13/30], Loss: 0.5423, Acc: 81.31%
# Epoch [14/30], Loss: 0.5170, Acc: 82.14%
# Epoch [15/30], Loss: 0.4930, Acc: 83.10%
# Epoch [16/30], Loss: 0.4669, Acc: 83.65%
# Epoch [17/30], Loss: 0.4420, Acc: 84.56%
# Epoch [18/30], Loss: 0.4285, Acc: 85.17%
# Epoch [19/30], Loss: 0.4074, Acc: 85.87%
# Epoch [20/30], Loss: 0.3874, Acc: 86.45%
# Epoch [21/30], Loss: 0.3771, Acc: 86.96%
# Epoch [22/30], Loss: 0.3565, Acc: 87.72%
# Epoch [23/30], Loss: 0.3456, Acc: 87.97%
# Epoch [24/30], Loss: 0.3330, Acc: 88.31%
# Epoch [25/30], Loss: 0.3188, Acc: 88.91%
# Epoch [26/30], Loss: 0.3047, Acc: 89.34%
# Epoch [27/30], Loss: 0.2935, Acc: 89.66%
# Epoch [28/30], Loss: 0.2864, Acc: 89.83%
# Epoch [29/30], Loss: 0.2703, Acc: 90.55%
# Epoch [30/30], Loss: 0.2664, Acc: 90.79%
# Test Accuracy: 79.12%
#
# --- Config: Act=relu, Init=random, Optim=sgd ---
# Epoch [1/30], Loss: 1.5197, Acc: 45.11%
# Epoch [2/30], Loss: 1.1321, Acc: 59.83%
# Epoch [3/30], Loss: 0.9869, Acc: 65.25%
# Epoch [4/30], Loss: 0.9005, Acc: 68.02%
# Epoch [5/30], Loss: 0.8347, Acc: 70.67%
# Epoch [6/30], Loss: 0.7906, Acc: 72.23%
# Epoch [7/30], Loss: 0.7476, Acc: 73.75%
# Epoch [8/30], Loss: 0.7178, Acc: 74.80%
# Epoch [9/30], Loss: 0.6844, Acc: 76.15%
# Epoch [10/30], Loss: 0.6541, Acc: 77.11%
# Epoch [11/30], Loss: 0.6357, Acc: 77.76%
# Epoch [12/30], Loss: 0.6105, Acc: 78.73%
# Epoch [13/30], Loss: 0.5932, Acc: 79.29%
# Epoch [14/30], Loss: 0.5760, Acc: 79.71%
# Epoch [15/30], Loss: 0.5572, Acc: 80.55%
# Epoch [16/30], Loss: 0.5412, Acc: 81.05%
# Epoch [17/30], Loss: 0.5254, Acc: 81.71%
# Epoch [18/30], Loss: 0.5113, Acc: 82.11%
# Epoch [19/30], Loss: 0.4951, Acc: 82.72%
# Epoch [20/30], Loss: 0.4840, Acc: 83.03%
# Epoch [21/30], Loss: 0.4687, Acc: 83.66%
# Epoch [22/30], Loss: 0.4590, Acc: 84.01%
# Epoch [23/30], Loss: 0.4489, Acc: 84.30%
# Epoch [24/30], Loss: 0.4361, Acc: 84.57%
# Epoch [25/30], Loss: 0.4209, Acc: 85.26%
# Epoch [26/30], Loss: 0.4119, Acc: 85.56%
# Epoch [27/30], Loss: 0.4021, Acc: 85.90%
# Epoch [28/30], Loss: 0.3929, Acc: 86.10%
# Epoch [29/30], Loss: 0.3858, Acc: 86.58%
# Epoch [30/30], Loss: 0.3724, Acc: 86.99%
# Test Accuracy: 80.92%
#
# --- Config: Act=relu, Init=random, Optim=adam ---
# Epoch [1/30], Loss: 1.3620, Acc: 50.61%
# Epoch [2/30], Loss: 1.0365, Acc: 63.33%
# Epoch [3/30], Loss: 0.8985, Acc: 68.69%
# Epoch [4/30], Loss: 0.8131, Acc: 71.82%
# Epoch [5/30], Loss: 0.7396, Acc: 74.47%
# Epoch [6/30], Loss: 0.6837, Acc: 76.43%
# Epoch [7/30], Loss: 0.6355, Acc: 77.99%
# Epoch [8/30], Loss: 0.5972, Acc: 79.38%
# Epoch [9/30], Loss: 0.5585, Acc: 80.70%
# Epoch [10/30], Loss: 0.5280, Acc: 81.83%
# Epoch [11/30], Loss: 0.5016, Acc: 82.76%
# Epoch [12/30], Loss: 0.4739, Acc: 83.41%
# Epoch [13/30], Loss: 0.4541, Acc: 84.30%
# Epoch [14/30], Loss: 0.4346, Acc: 84.80%
# Epoch [15/30], Loss: 0.4145, Acc: 85.66%
# Epoch [16/30], Loss: 0.3890, Acc: 86.42%
# Epoch [17/30], Loss: 0.3757, Acc: 86.92%
# Epoch [18/30], Loss: 0.3594, Acc: 87.48%
# Epoch [19/30], Loss: 0.3467, Acc: 87.95%
# Epoch [20/30], Loss: 0.3320, Acc: 88.38%
# Epoch [21/30], Loss: 0.3216, Acc: 88.88%
# Epoch [22/30], Loss: 0.3032, Acc: 89.24%
# Epoch [23/30], Loss: 0.2956, Acc: 89.58%
# Epoch [24/30], Loss: 0.2855, Acc: 89.94%
# Epoch [25/30], Loss: 0.2736, Acc: 90.34%
# Epoch [26/30], Loss: 0.2620, Acc: 90.88%
# Epoch [27/30], Loss: 0.2576, Acc: 91.06%
# Epoch [28/30], Loss: 0.2484, Acc: 91.22%
# Epoch [29/30], Loss: 0.2418, Acc: 91.52%
# Epoch [30/30], Loss: 0.2329, Acc: 91.82%
# Test Accuracy: 81.59%
#
# --- Config: Act=relu, Init=random, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.6096, Acc: 43.08%
# Epoch [2/30], Loss: 1.1899, Acc: 57.16%
# Epoch [3/30], Loss: 1.0480, Acc: 62.98%
# Epoch [4/30], Loss: 0.9540, Acc: 66.74%
# Epoch [5/30], Loss: 0.8857, Acc: 69.16%
# Epoch [6/30], Loss: 0.8227, Acc: 71.55%
# Epoch [7/30], Loss: 0.7720, Acc: 73.39%
# Epoch [8/30], Loss: 0.7306, Acc: 74.81%
# Epoch [9/30], Loss: 0.6913, Acc: 76.10%
# Epoch [10/30], Loss: 0.6538, Acc: 77.30%
# Epoch [11/30], Loss: 0.6199, Acc: 78.81%
# Epoch [12/30], Loss: 0.5923, Acc: 79.62%
# Epoch [13/30], Loss: 0.5605, Acc: 80.69%
# Epoch [14/30], Loss: 0.5357, Acc: 81.43%
# Epoch [15/30], Loss: 0.5075, Acc: 82.50%
# Epoch [16/30], Loss: 0.4880, Acc: 83.15%
# Epoch [17/30], Loss: 0.4691, Acc: 83.79%
# Epoch [18/30], Loss: 0.4473, Acc: 84.46%
# Epoch [19/30], Loss: 0.4328, Acc: 85.05%
# Epoch [20/30], Loss: 0.4078, Acc: 85.91%
# Epoch [21/30], Loss: 0.3986, Acc: 86.26%
# Epoch [22/30], Loss: 0.3819, Acc: 86.71%
# Epoch [23/30], Loss: 0.3649, Acc: 87.43%
# Epoch [24/30], Loss: 0.3533, Acc: 87.65%
# Epoch [25/30], Loss: 0.3403, Acc: 88.10%
# Epoch [26/30], Loss: 0.3228, Acc: 88.66%
# Epoch [27/30], Loss: 0.3167, Acc: 88.92%
# Epoch [28/30], Loss: 0.3030, Acc: 89.44%
# Epoch [29/30], Loss: 0.2920, Acc: 89.77%
# Epoch [30/30], Loss: 0.2827, Acc: 90.17%
# Test Accuracy: 81.93%
#
# --- Config: Act=tanh, Init=xavier, Optim=sgd ---
# Epoch [1/30], Loss: 1.7015, Acc: 40.39%
# Epoch [2/30], Loss: 1.3305, Acc: 52.54%
# Epoch [3/30], Loss: 1.1881, Acc: 57.66%
# Epoch [4/30], Loss: 1.0977, Acc: 60.95%
# Epoch [5/30], Loss: 1.0346, Acc: 63.21%
# Epoch [6/30], Loss: 0.9855, Acc: 65.12%
# Epoch [7/30], Loss: 0.9420, Acc: 66.72%
# Epoch [8/30], Loss: 0.9086, Acc: 67.97%
# Epoch [9/30], Loss: 0.8786, Acc: 69.20%
# Epoch [10/30], Loss: 0.8571, Acc: 70.01%
# Epoch [11/30], Loss: 0.8293, Acc: 70.83%
# Epoch [12/30], Loss: 0.8126, Acc: 71.45%
# Epoch [13/30], Loss: 0.7893, Acc: 72.28%
# Epoch [14/30], Loss: 0.7764, Acc: 72.80%
# Epoch [15/30], Loss: 0.7593, Acc: 73.47%
# Epoch [16/30], Loss: 0.7436, Acc: 73.97%
# Epoch [17/30], Loss: 0.7223, Acc: 74.78%
# Epoch [18/30], Loss: 0.7099, Acc: 75.21%
# Epoch [19/30], Loss: 0.6957, Acc: 75.61%
# Epoch [20/30], Loss: 0.6786, Acc: 76.17%
# Epoch [21/30], Loss: 0.6666, Acc: 76.61%
# Epoch [22/30], Loss: 0.6575, Acc: 76.88%
# Epoch [23/30], Loss: 0.6461, Acc: 77.31%
# Epoch [24/30], Loss: 0.6363, Acc: 77.73%
# Epoch [25/30], Loss: 0.6256, Acc: 77.98%
# Epoch [26/30], Loss: 0.6111, Acc: 78.61%
# Epoch [27/30], Loss: 0.6005, Acc: 79.01%
# Epoch [28/30], Loss: 0.5926, Acc: 79.34%
# Epoch [29/30], Loss: 0.5792, Acc: 79.99%
# Epoch [30/30], Loss: 0.5731, Acc: 79.80%
# Test Accuracy: 74.62%
#
# --- Config: Act=tanh, Init=xavier, Optim=adam ---
# Epoch [1/30], Loss: 1.6564, Acc: 44.09%
# Epoch [2/30], Loss: 1.1739, Acc: 57.99%
# Epoch [3/30], Loss: 1.0023, Acc: 64.64%
# Epoch [4/30], Loss: 0.9162, Acc: 67.81%
# Epoch [5/30], Loss: 0.8606, Acc: 69.81%
# Epoch [6/30], Loss: 0.8075, Acc: 71.74%
# Epoch [7/30], Loss: 0.7673, Acc: 73.03%
# Epoch [8/30], Loss: 0.7295, Acc: 74.50%
# Epoch [9/30], Loss: 0.6992, Acc: 75.32%
# Epoch [10/30], Loss: 0.6802, Acc: 76.30%
# Epoch [11/30], Loss: 0.6457, Acc: 77.64%
# Epoch [12/30], Loss: 0.6230, Acc: 78.09%
# Epoch [13/30], Loss: 0.6083, Acc: 78.82%
# Epoch [14/30], Loss: 0.5848, Acc: 79.43%
# Epoch [15/30], Loss: 0.5540, Acc: 80.62%
# Epoch [16/30], Loss: 0.5415, Acc: 81.06%
# Epoch [17/30], Loss: 0.5234, Acc: 81.69%
# Epoch [18/30], Loss: 0.4997, Acc: 82.46%
# Epoch [19/30], Loss: 0.4923, Acc: 82.69%
# Epoch [20/30], Loss: 0.4736, Acc: 83.42%
# Epoch [21/30], Loss: 0.4565, Acc: 83.89%
# Epoch [22/30], Loss: 0.4455, Acc: 84.43%
# Epoch [23/30], Loss: 0.4326, Acc: 84.84%
# Epoch [24/30], Loss: 0.4195, Acc: 85.32%
# Epoch [25/30], Loss: 0.4016, Acc: 85.81%
# Epoch [26/30], Loss: 0.3935, Acc: 86.12%
# Epoch [27/30], Loss: 0.3843, Acc: 86.49%
# Epoch [28/30], Loss: 0.3827, Acc: 86.55%
# Epoch [29/30], Loss: 0.3674, Acc: 87.12%
# Epoch [30/30], Loss: 0.3573, Acc: 87.28%
# Test Accuracy: 78.32%
#
# --- Config: Act=tanh, Init=xavier, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.8075, Acc: 39.57%
# Epoch [2/30], Loss: 1.2623, Acc: 55.13%
# Epoch [3/30], Loss: 1.0957, Acc: 61.06%
# Epoch [4/30], Loss: 0.9863, Acc: 65.30%
# Epoch [5/30], Loss: 0.9183, Acc: 67.70%
# Epoch [6/30], Loss: 0.8681, Acc: 69.59%
# Epoch [7/30], Loss: 0.8211, Acc: 71.18%
# Epoch [8/30], Loss: 0.7848, Acc: 72.75%
# Epoch [9/30], Loss: 0.7560, Acc: 73.63%
# Epoch [10/30], Loss: 0.7199, Acc: 74.87%
# Epoch [11/30], Loss: 0.6995, Acc: 75.69%
# Epoch [12/30], Loss: 0.6724, Acc: 76.49%
# Epoch [13/30], Loss: 0.6462, Acc: 77.46%
# Epoch [14/30], Loss: 0.6269, Acc: 78.17%
# Epoch [15/30], Loss: 0.6041, Acc: 78.82%
# Epoch [16/30], Loss: 0.5810, Acc: 79.67%
# Epoch [17/30], Loss: 0.5664, Acc: 80.03%
# Epoch [18/30], Loss: 0.5517, Acc: 80.70%
# Epoch [19/30], Loss: 0.5301, Acc: 81.35%
# Epoch [20/30], Loss: 0.5186, Acc: 81.88%
# Epoch [21/30], Loss: 0.5021, Acc: 82.35%
# Epoch [22/30], Loss: 0.4911, Acc: 82.73%
# Epoch [23/30], Loss: 0.4728, Acc: 83.44%
# Epoch [24/30], Loss: 0.4578, Acc: 83.98%
# Epoch [25/30], Loss: 0.4480, Acc: 84.15%
# Epoch [26/30], Loss: 0.4358, Acc: 84.60%
# Epoch [27/30], Loss: 0.4212, Acc: 85.23%
# Epoch [28/30], Loss: 0.4104, Acc: 85.54%
# Epoch [29/30], Loss: 0.3962, Acc: 86.16%
# Epoch [30/30], Loss: 0.3865, Acc: 86.37%
# Test Accuracy: 77.17%
#
# --- Config: Act=tanh, Init=kaiming, Optim=sgd ---
# Epoch [1/30], Loss: 1.7775, Acc: 38.05%
# Epoch [2/30], Loss: 1.4236, Acc: 49.06%
# Epoch [3/30], Loss: 1.2884, Acc: 53.74%
# Epoch [4/30], Loss: 1.1931, Acc: 57.29%
# Epoch [5/30], Loss: 1.1315, Acc: 59.63%
# Epoch [6/30], Loss: 1.0812, Acc: 61.53%
# Epoch [7/30], Loss: 1.0391, Acc: 63.16%
# Epoch [8/30], Loss: 1.0059, Acc: 64.69%
# Epoch [9/30], Loss: 0.9734, Acc: 65.52%
# Epoch [10/30], Loss: 0.9463, Acc: 66.56%
# Epoch [11/30], Loss: 0.9237, Acc: 67.31%
# Epoch [12/30], Loss: 0.9008, Acc: 68.26%
# Epoch [13/30], Loss: 0.8829, Acc: 68.91%
# Epoch [14/30], Loss: 0.8677, Acc: 69.63%
# Epoch [15/30], Loss: 0.8511, Acc: 69.97%
# Epoch [16/30], Loss: 0.8328, Acc: 70.62%
# Epoch [17/30], Loss: 0.8250, Acc: 71.02%
# Epoch [18/30], Loss: 0.8054, Acc: 71.66%
# Epoch [19/30], Loss: 0.7986, Acc: 71.83%
# Epoch [20/30], Loss: 0.7828, Acc: 72.53%
# Epoch [21/30], Loss: 0.7752, Acc: 72.80%
# Epoch [22/30], Loss: 0.7614, Acc: 73.36%
# Epoch [23/30], Loss: 0.7564, Acc: 73.32%
# Epoch [24/30], Loss: 0.7423, Acc: 74.11%
# Epoch [25/30], Loss: 0.7286, Acc: 74.45%
# Epoch [26/30], Loss: 0.7212, Acc: 74.55%
# Epoch [27/30], Loss: 0.7097, Acc: 74.95%
# Epoch [28/30], Loss: 0.7039, Acc: 75.21%
# Epoch [29/30], Loss: 0.6949, Acc: 75.71%
# Epoch [30/30], Loss: 0.6838, Acc: 75.99%
# Test Accuracy: 71.35%
#
# --- Config: Act=tanh, Init=kaiming, Optim=adam ---
# Epoch [1/30], Loss: 1.6643, Acc: 44.30%
# Epoch [2/30], Loss: 1.1731, Acc: 58.52%
# Epoch [3/30], Loss: 1.0245, Acc: 63.58%
# Epoch [4/30], Loss: 0.9346, Acc: 67.19%
# Epoch [5/30], Loss: 0.8682, Acc: 69.28%
# Epoch [6/30], Loss: 0.8153, Acc: 71.34%
# Epoch [7/30], Loss: 0.7782, Acc: 72.72%
# Epoch [8/30], Loss: 0.7333, Acc: 74.53%
# Epoch [9/30], Loss: 0.7074, Acc: 75.45%
# Epoch [10/30], Loss: 0.6767, Acc: 76.26%
# Epoch [11/30], Loss: 0.6537, Acc: 77.29%
# Epoch [12/30], Loss: 0.6287, Acc: 78.13%
# Epoch [13/30], Loss: 0.6040, Acc: 79.04%
# Epoch [14/30], Loss: 0.5835, Acc: 79.62%
# Epoch [15/30], Loss: 0.5689, Acc: 80.22%
# Epoch [16/30], Loss: 0.5427, Acc: 81.00%
# Epoch [17/30], Loss: 0.5263, Acc: 81.53%
# Epoch [18/30], Loss: 0.5063, Acc: 82.05%
# Epoch [19/30], Loss: 0.4893, Acc: 82.70%
# Epoch [20/30], Loss: 0.4745, Acc: 83.28%
# Epoch [21/30], Loss: 0.4655, Acc: 83.65%
# Epoch [22/30], Loss: 0.4456, Acc: 84.39%
# Epoch [23/30], Loss: 0.4270, Acc: 84.97%
# Epoch [24/30], Loss: 0.4221, Acc: 85.14%
# Epoch [25/30], Loss: 0.4125, Acc: 85.49%
# Epoch [26/30], Loss: 0.3903, Acc: 86.20%
# Epoch [27/30], Loss: 0.3880, Acc: 86.29%
# Epoch [28/30], Loss: 0.3767, Acc: 86.78%
# Epoch [29/30], Loss: 0.3694, Acc: 86.89%
# Epoch [30/30], Loss: 0.3524, Acc: 87.57%
# Test Accuracy: 77.67%
#
# --- Config: Act=tanh, Init=kaiming, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.7718, Acc: 41.00%
# Epoch [2/30], Loss: 1.2489, Acc: 55.40%
# Epoch [3/30], Loss: 1.0804, Acc: 61.61%
# Epoch [4/30], Loss: 0.9858, Acc: 64.98%
# Epoch [5/30], Loss: 0.9093, Acc: 68.08%
# Epoch [6/30], Loss: 0.8549, Acc: 70.20%
# Epoch [7/30], Loss: 0.8125, Acc: 71.52%
# Epoch [8/30], Loss: 0.7684, Acc: 73.25%
# Epoch [9/30], Loss: 0.7391, Acc: 74.37%
# Epoch [10/30], Loss: 0.7079, Acc: 75.35%
# Epoch [11/30], Loss: 0.6845, Acc: 76.03%
# Epoch [12/30], Loss: 0.6616, Acc: 77.10%
# Epoch [13/30], Loss: 0.6328, Acc: 77.94%
# Epoch [14/30], Loss: 0.6117, Acc: 78.52%
# Epoch [15/30], Loss: 0.5917, Acc: 79.35%
# Epoch [16/30], Loss: 0.5738, Acc: 79.80%
# Epoch [17/30], Loss: 0.5570, Acc: 80.57%
# Epoch [18/30], Loss: 0.5352, Acc: 81.26%
# Epoch [19/30], Loss: 0.5201, Acc: 81.58%
# Epoch [20/30], Loss: 0.5047, Acc: 82.37%
# Epoch [21/30], Loss: 0.4850, Acc: 83.01%
# Epoch [22/30], Loss: 0.4777, Acc: 83.13%
# Epoch [23/30], Loss: 0.4569, Acc: 84.07%
# Epoch [24/30], Loss: 0.4440, Acc: 84.35%
# Epoch [25/30], Loss: 0.4352, Acc: 84.78%
# Epoch [26/30], Loss: 0.4229, Acc: 85.28%
# Epoch [27/30], Loss: 0.4081, Acc: 85.71%
# Epoch [28/30], Loss: 0.3955, Acc: 86.07%
# Epoch [29/30], Loss: 0.3923, Acc: 86.20%
# Epoch [30/30], Loss: 0.3740, Acc: 86.84%
# Test Accuracy: 77.11%
#
# --- Config: Act=tanh, Init=random, Optim=sgd ---
# Epoch [1/30], Loss: 1.6247, Acc: 41.79%
# Epoch [2/30], Loss: 1.2933, Acc: 53.56%
# Epoch [3/30], Loss: 1.1558, Acc: 58.89%
# Epoch [4/30], Loss: 1.0644, Acc: 62.55%
# Epoch [5/30], Loss: 0.9981, Acc: 64.72%
# Epoch [6/30], Loss: 0.9409, Acc: 66.86%
# Epoch [7/30], Loss: 0.8979, Acc: 68.22%
# Epoch [8/30], Loss: 0.8627, Acc: 69.62%
# Epoch [9/30], Loss: 0.8297, Acc: 70.78%
# Epoch [10/30], Loss: 0.8028, Acc: 71.90%
# Epoch [11/30], Loss: 0.7809, Acc: 72.55%
# Epoch [12/30], Loss: 0.7562, Acc: 73.41%
# Epoch [13/30], Loss: 0.7412, Acc: 74.06%
# Epoch [14/30], Loss: 0.7186, Acc: 74.95%
# Epoch [15/30], Loss: 0.7007, Acc: 75.25%
# Epoch [16/30], Loss: 0.6849, Acc: 75.95%
# Epoch [17/30], Loss: 0.6632, Acc: 76.69%
# Epoch [18/30], Loss: 0.6527, Acc: 77.23%
# Epoch [19/30], Loss: 0.6360, Acc: 77.83%
# Epoch [20/30], Loss: 0.6192, Acc: 78.31%
# Epoch [21/30], Loss: 0.6035, Acc: 78.97%
# Epoch [22/30], Loss: 0.5964, Acc: 79.06%
# Epoch [23/30], Loss: 0.5876, Acc: 79.31%
# Epoch [24/30], Loss: 0.5679, Acc: 80.02%
# Epoch [25/30], Loss: 0.5604, Acc: 80.42%
# Epoch [26/30], Loss: 0.5495, Acc: 80.63%
# Epoch [27/30], Loss: 0.5349, Acc: 81.12%
# Epoch [28/30], Loss: 0.5195, Acc: 81.68%
# Epoch [29/30], Loss: 0.5169, Acc: 81.96%
# Epoch [30/30], Loss: 0.5031, Acc: 82.17%
# Test Accuracy: 75.21%
#
# --- Config: Act=tanh, Init=random, Optim=adam ---
# Epoch [1/30], Loss: 1.4309, Acc: 48.39%
# Epoch [2/30], Loss: 1.1517, Acc: 59.05%
# Epoch [3/30], Loss: 1.0088, Acc: 64.29%
# Epoch [4/30], Loss: 0.9156, Acc: 67.88%
# Epoch [5/30], Loss: 0.8524, Acc: 70.11%
# Epoch [6/30], Loss: 0.8077, Acc: 71.57%
# Epoch [7/30], Loss: 0.7735, Acc: 72.84%
# Epoch [8/30], Loss: 0.7462, Acc: 73.84%
# Epoch [9/30], Loss: 0.7120, Acc: 75.38%
# Epoch [10/30], Loss: 0.6867, Acc: 76.04%
# Epoch [11/30], Loss: 0.6532, Acc: 77.13%
# Epoch [12/30], Loss: 0.6366, Acc: 77.84%
# Epoch [13/30], Loss: 0.6125, Acc: 78.48%
# Epoch [14/30], Loss: 0.5946, Acc: 79.17%
# Epoch [15/30], Loss: 0.5745, Acc: 79.91%
# Epoch [16/30], Loss: 0.5524, Acc: 80.79%
# Epoch [17/30], Loss: 0.5351, Acc: 81.26%
# Epoch [18/30], Loss: 0.5214, Acc: 81.59%
# Epoch [19/30], Loss: 0.5060, Acc: 82.20%
# Epoch [20/30], Loss: 0.4898, Acc: 82.90%
# Epoch [21/30], Loss: 0.4779, Acc: 83.21%
# Epoch [22/30], Loss: 0.4640, Acc: 83.73%
# Epoch [23/30], Loss: 0.4543, Acc: 84.22%
# Epoch [24/30], Loss: 0.4391, Acc: 84.62%
# Epoch [25/30], Loss: 0.4255, Acc: 85.18%
# Epoch [26/30], Loss: 0.4115, Acc: 85.51%
# Epoch [27/30], Loss: 0.4025, Acc: 85.93%
# Epoch [28/30], Loss: 0.3848, Acc: 86.44%
# Epoch [29/30], Loss: 0.3785, Acc: 86.61%
# Epoch [30/30], Loss: 0.3643, Acc: 87.08%
# Test Accuracy: 78.91%
#
# --- Config: Act=tanh, Init=random, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.6097, Acc: 41.79%
# Epoch [2/30], Loss: 1.2648, Acc: 54.57%
# Epoch [3/30], Loss: 1.1162, Acc: 60.34%
# Epoch [4/30], Loss: 1.0053, Acc: 64.65%
# Epoch [5/30], Loss: 0.9345, Acc: 67.15%
# Epoch [6/30], Loss: 0.8809, Acc: 69.19%
# Epoch [7/30], Loss: 0.8394, Acc: 70.71%
# Epoch [8/30], Loss: 0.7978, Acc: 72.33%
# Epoch [9/30], Loss: 0.7640, Acc: 73.52%
# Epoch [10/30], Loss: 0.7380, Acc: 74.27%
# Epoch [11/30], Loss: 0.7092, Acc: 75.17%
# Epoch [12/30], Loss: 0.6870, Acc: 75.96%
# Epoch [13/30], Loss: 0.6641, Acc: 77.00%
# Epoch [14/30], Loss: 0.6455, Acc: 77.45%
# Epoch [15/30], Loss: 0.6214, Acc: 78.25%
# Epoch [16/30], Loss: 0.6035, Acc: 79.02%
# Epoch [17/30], Loss: 0.5814, Acc: 79.75%
# Epoch [18/30], Loss: 0.5692, Acc: 80.05%
# Epoch [19/30], Loss: 0.5502, Acc: 80.68%
# Epoch [20/30], Loss: 0.5322, Acc: 81.32%
# Epoch [21/30], Loss: 0.5226, Acc: 81.80%
# Epoch [22/30], Loss: 0.5060, Acc: 82.27%
# Epoch [23/30], Loss: 0.4908, Acc: 82.83%
# Epoch [24/30], Loss: 0.4725, Acc: 83.41%
# Epoch [25/30], Loss: 0.4622, Acc: 83.94%
# Epoch [26/30], Loss: 0.4456, Acc: 84.39%
# Epoch [27/30], Loss: 0.4417, Acc: 84.48%
# Epoch [28/30], Loss: 0.4272, Acc: 84.97%
# Epoch [29/30], Loss: 0.4167, Acc: 85.48%
# Epoch [30/30], Loss: 0.4050, Acc: 85.88%
# Test Accuracy: 73.22%
#
# --- Config: Act=leaky_relu, Init=xavier, Optim=sgd ---
# Epoch [1/30], Loss: 1.5927, Acc: 42.73%
# Epoch [2/30], Loss: 1.2492, Acc: 55.19%
# Epoch [3/30], Loss: 1.0947, Acc: 61.41%
# Epoch [4/30], Loss: 1.0026, Acc: 64.56%
# Epoch [5/30], Loss: 0.9395, Acc: 66.98%
# Epoch [6/30], Loss: 0.8856, Acc: 68.72%
# Epoch [7/30], Loss: 0.8441, Acc: 70.31%
# Epoch [8/30], Loss: 0.8065, Acc: 71.58%
# Epoch [9/30], Loss: 0.7789, Acc: 72.73%
# Epoch [10/30], Loss: 0.7513, Acc: 73.78%
# Epoch [11/30], Loss: 0.7264, Acc: 74.63%
# Epoch [12/30], Loss: 0.7008, Acc: 75.28%
# Epoch [13/30], Loss: 0.6796, Acc: 76.23%
# Epoch [14/30], Loss: 0.6630, Acc: 76.53%
# Epoch [15/30], Loss: 0.6440, Acc: 77.49%
# Epoch [16/30], Loss: 0.6268, Acc: 77.96%
# Epoch [17/30], Loss: 0.6104, Acc: 78.49%
# Epoch [18/30], Loss: 0.5986, Acc: 78.96%
# Epoch [19/30], Loss: 0.5824, Acc: 79.54%
# Epoch [20/30], Loss: 0.5697, Acc: 79.93%
# Epoch [21/30], Loss: 0.5589, Acc: 80.31%
# Epoch [22/30], Loss: 0.5484, Acc: 80.73%
# Epoch [23/30], Loss: 0.5285, Acc: 81.34%
# Epoch [24/30], Loss: 0.5207, Acc: 81.60%
# Epoch [25/30], Loss: 0.5068, Acc: 82.14%
# Epoch [26/30], Loss: 0.4960, Acc: 82.50%
# Epoch [27/30], Loss: 0.4909, Acc: 82.71%
# Epoch [28/30], Loss: 0.4803, Acc: 82.96%
# Epoch [29/30], Loss: 0.4678, Acc: 83.49%
# Epoch [30/30], Loss: 0.4623, Acc: 83.65%
# Test Accuracy: 79.33%
#
# --- Config: Act=leaky_relu, Init=xavier, Optim=adam ---
# Epoch [1/30], Loss: 1.5397, Acc: 44.74%
# Epoch [2/30], Loss: 1.1270, Acc: 60.14%
# Epoch [3/30], Loss: 0.9698, Acc: 66.07%
# Epoch [4/30], Loss: 0.8769, Acc: 69.58%
# Epoch [5/30], Loss: 0.8017, Acc: 72.28%
# Epoch [6/30], Loss: 0.7454, Acc: 74.23%
# Epoch [7/30], Loss: 0.6878, Acc: 76.40%
# Epoch [8/30], Loss: 0.6355, Acc: 78.02%
# Epoch [9/30], Loss: 0.5963, Acc: 79.41%
# Epoch [10/30], Loss: 0.5568, Acc: 80.66%
# Epoch [11/30], Loss: 0.5241, Acc: 81.87%
# Epoch [12/30], Loss: 0.4813, Acc: 83.18%
# Epoch [13/30], Loss: 0.4488, Acc: 84.51%
# Epoch [14/30], Loss: 0.4235, Acc: 85.15%
# Epoch [15/30], Loss: 0.3939, Acc: 86.13%
# Epoch [16/30], Loss: 0.3674, Acc: 87.16%
# Epoch [17/30], Loss: 0.3451, Acc: 87.81%
# Epoch [18/30], Loss: 0.3265, Acc: 88.59%
# Epoch [19/30], Loss: 0.3041, Acc: 89.37%
# Epoch [20/30], Loss: 0.2854, Acc: 90.07%
# Epoch [21/30], Loss: 0.2683, Acc: 90.49%
# Epoch [22/30], Loss: 0.2532, Acc: 91.12%
# Epoch [23/30], Loss: 0.2445, Acc: 91.43%
# Epoch [24/30], Loss: 0.2239, Acc: 92.09%
# Epoch [25/30], Loss: 0.2172, Acc: 92.33%
# Epoch [26/30], Loss: 0.2037, Acc: 92.86%
# Epoch [27/30], Loss: 0.1955, Acc: 92.96%
# Epoch [28/30], Loss: 0.1836, Acc: 93.64%
# Epoch [29/30], Loss: 0.1785, Acc: 93.73%
# Epoch [30/30], Loss: 0.1702, Acc: 94.03%
# Test Accuracy: 83.02%
#
# --- Config: Act=leaky_relu, Init=xavier, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.8506, Acc: 40.82%
# Epoch [2/30], Loss: 1.1900, Acc: 57.81%
# Epoch [3/30], Loss: 0.9753, Acc: 65.71%
# Epoch [4/30], Loss: 0.8496, Acc: 70.36%
# Epoch [5/30], Loss: 0.7541, Acc: 73.71%
# Epoch [6/30], Loss: 0.6791, Acc: 76.33%
# Epoch [7/30], Loss: 0.6174, Acc: 78.65%
# Epoch [8/30], Loss: 0.5662, Acc: 80.31%
# Epoch [9/30], Loss: 0.5146, Acc: 82.17%
# Epoch [10/30], Loss: 0.4775, Acc: 83.23%
# Epoch [11/30], Loss: 0.4416, Acc: 84.71%
# Epoch [12/30], Loss: 0.4086, Acc: 85.82%
# Epoch [13/30], Loss: 0.3829, Acc: 86.68%
# Epoch [14/30], Loss: 0.3586, Acc: 87.45%
# Epoch [15/30], Loss: 0.3336, Acc: 88.36%
# Epoch [16/30], Loss: 0.3095, Acc: 89.25%
# Epoch [17/30], Loss: 0.2962, Acc: 89.79%
# Epoch [18/30], Loss: 0.2755, Acc: 90.41%
# Epoch [19/30], Loss: 0.2661, Acc: 90.73%
# Epoch [20/30], Loss: 0.2513, Acc: 91.35%
# Epoch [21/30], Loss: 0.2334, Acc: 91.87%
# Epoch [22/30], Loss: 0.2253, Acc: 92.06%
# Epoch [23/30], Loss: 0.2109, Acc: 92.53%
# Epoch [24/30], Loss: 0.2047, Acc: 92.93%
# Epoch [25/30], Loss: 0.1983, Acc: 93.14%
# Epoch [26/30], Loss: 0.1912, Acc: 93.45%
# Epoch [27/30], Loss: 0.1845, Acc: 93.69%
# Epoch [28/30], Loss: 0.1755, Acc: 93.88%
# Epoch [29/30], Loss: 0.1695, Acc: 94.18%
# Epoch [30/30], Loss: 0.1622, Acc: 94.33%
# Test Accuracy: 83.01%
#
# --- Config: Act=leaky_relu, Init=kaiming, Optim=sgd ---
# Epoch [1/30], Loss: 1.6650, Acc: 40.58%
# Epoch [2/30], Loss: 1.3382, Acc: 51.62%
# Epoch [3/30], Loss: 1.2072, Acc: 57.08%
# Epoch [4/30], Loss: 1.1185, Acc: 60.32%
# Epoch [5/30], Loss: 1.0505, Acc: 62.74%
# Epoch [6/30], Loss: 1.0012, Acc: 64.52%
# Epoch [7/30], Loss: 0.9594, Acc: 66.27%
# Epoch [8/30], Loss: 0.9257, Acc: 67.42%
# Epoch [9/30], Loss: 0.8914, Acc: 68.71%
# Epoch [10/30], Loss: 0.8635, Acc: 69.61%
# Epoch [11/30], Loss: 0.8352, Acc: 70.63%
# Epoch [12/30], Loss: 0.8157, Acc: 71.34%
# Epoch [13/30], Loss: 0.7948, Acc: 72.11%
# Epoch [14/30], Loss: 0.7753, Acc: 72.88%
# Epoch [15/30], Loss: 0.7514, Acc: 73.47%
# Epoch [16/30], Loss: 0.7369, Acc: 74.27%
# Epoch [17/30], Loss: 0.7175, Acc: 74.72%
# Epoch [18/30], Loss: 0.7026, Acc: 75.24%
# Epoch [19/30], Loss: 0.6936, Acc: 75.61%
# Epoch [20/30], Loss: 0.6751, Acc: 76.30%
# Epoch [21/30], Loss: 0.6629, Acc: 76.70%
# Epoch [22/30], Loss: 0.6499, Acc: 77.19%
# Epoch [23/30], Loss: 0.6361, Acc: 77.75%
# Epoch [24/30], Loss: 0.6248, Acc: 78.18%
# Epoch [25/30], Loss: 0.6146, Acc: 78.52%
# Epoch [26/30], Loss: 0.5975, Acc: 78.95%
# Epoch [27/30], Loss: 0.5921, Acc: 79.09%
# Epoch [28/30], Loss: 0.5820, Acc: 79.63%
# Epoch [29/30], Loss: 0.5712, Acc: 79.95%
# Epoch [30/30], Loss: 0.5594, Acc: 80.37%
# Test Accuracy: 77.81%
#
# --- Config: Act=leaky_relu, Init=kaiming, Optim=adam ---
# Epoch [1/30], Loss: 1.5040, Acc: 46.43%
# Epoch [2/30], Loss: 1.1224, Acc: 60.25%
# Epoch [3/30], Loss: 0.9820, Acc: 65.70%
# Epoch [4/30], Loss: 0.8814, Acc: 69.24%
# Epoch [5/30], Loss: 0.8124, Acc: 71.67%
# Epoch [6/30], Loss: 0.7439, Acc: 74.40%
# Epoch [7/30], Loss: 0.6870, Acc: 76.23%
# Epoch [8/30], Loss: 0.6462, Acc: 77.66%
# Epoch [9/30], Loss: 0.5946, Acc: 79.56%
# Epoch [10/30], Loss: 0.5546, Acc: 80.70%
# Epoch [11/30], Loss: 0.5174, Acc: 81.98%
# Epoch [12/30], Loss: 0.4774, Acc: 83.45%
# Epoch [13/30], Loss: 0.4503, Acc: 84.32%
# Epoch [14/30], Loss: 0.4189, Acc: 85.47%
# Epoch [15/30], Loss: 0.3885, Acc: 86.28%
# Epoch [16/30], Loss: 0.3638, Acc: 87.23%
# Epoch [17/30], Loss: 0.3431, Acc: 88.00%
# Epoch [18/30], Loss: 0.3141, Acc: 89.07%
# Epoch [19/30], Loss: 0.2954, Acc: 89.67%
# Epoch [20/30], Loss: 0.2747, Acc: 90.41%
# Epoch [21/30], Loss: 0.2605, Acc: 90.65%
# Epoch [22/30], Loss: 0.2400, Acc: 91.46%
# Epoch [23/30], Loss: 0.2273, Acc: 92.11%
# Epoch [24/30], Loss: 0.2243, Acc: 92.14%
# Epoch [25/30], Loss: 0.2051, Acc: 92.87%
# Epoch [26/30], Loss: 0.1966, Acc: 93.10%
# Epoch [27/30], Loss: 0.1882, Acc: 93.45%
# Epoch [28/30], Loss: 0.1814, Acc: 93.56%
# Epoch [29/30], Loss: 0.1783, Acc: 93.72%
# Epoch [30/30], Loss: 0.1593, Acc: 94.27%
# Test Accuracy: 82.62%
#
# --- Config: Act=leaky_relu, Init=kaiming, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.9121, Acc: 41.16%
# Epoch [2/30], Loss: 1.2119, Acc: 57.26%
# Epoch [3/30], Loss: 0.9966, Acc: 65.21%
# Epoch [4/30], Loss: 0.8609, Acc: 69.94%
# Epoch [5/30], Loss: 0.7715, Acc: 73.46%
# Epoch [6/30], Loss: 0.6947, Acc: 75.93%
# Epoch [7/30], Loss: 0.6294, Acc: 78.11%
# Epoch [8/30], Loss: 0.5759, Acc: 79.82%
# Epoch [9/30], Loss: 0.5294, Acc: 81.59%
# Epoch [10/30], Loss: 0.4897, Acc: 82.76%
# Epoch [11/30], Loss: 0.4515, Acc: 84.36%
# Epoch [12/30], Loss: 0.4196, Acc: 85.35%
# Epoch [13/30], Loss: 0.3880, Acc: 86.35%
# Epoch [14/30], Loss: 0.3602, Acc: 87.51%
# Epoch [15/30], Loss: 0.3381, Acc: 88.07%
# Epoch [16/30], Loss: 0.3138, Acc: 88.90%
# Epoch [17/30], Loss: 0.2968, Acc: 89.42%
# Epoch [18/30], Loss: 0.2863, Acc: 89.99%
# Epoch [19/30], Loss: 0.2680, Acc: 90.59%
# Epoch [20/30], Loss: 0.2530, Acc: 91.13%
# Epoch [21/30], Loss: 0.2374, Acc: 91.78%
# Epoch [22/30], Loss: 0.2266, Acc: 92.02%
# Epoch [23/30], Loss: 0.2157, Acc: 92.42%
# Epoch [24/30], Loss: 0.2074, Acc: 92.80%
# Epoch [25/30], Loss: 0.2001, Acc: 92.96%
# Epoch [26/30], Loss: 0.1979, Acc: 92.99%
# Epoch [27/30], Loss: 0.1817, Acc: 93.62%
# Epoch [28/30], Loss: 0.1834, Acc: 93.55%
# Epoch [29/30], Loss: 0.1733, Acc: 94.02%
# Epoch [30/30], Loss: 0.1701, Acc: 94.20%
# Test Accuracy: 81.98%
#
# --- Config: Act=leaky_relu, Init=random, Optim=sgd ---
# Epoch [1/30], Loss: 1.4998, Acc: 45.64%
# Epoch [2/30], Loss: 1.1268, Acc: 59.86%
# Epoch [3/30], Loss: 0.9913, Acc: 65.11%
# Epoch [4/30], Loss: 0.9085, Acc: 67.89%
# Epoch [5/30], Loss: 0.8400, Acc: 70.49%
# Epoch [6/30], Loss: 0.7957, Acc: 72.03%
# Epoch [7/30], Loss: 0.7512, Acc: 73.70%
# Epoch [8/30], Loss: 0.7143, Acc: 75.13%
# Epoch [9/30], Loss: 0.6856, Acc: 76.03%
# Epoch [10/30], Loss: 0.6540, Acc: 77.08%
# Epoch [11/30], Loss: 0.6348, Acc: 77.67%
# Epoch [12/30], Loss: 0.6130, Acc: 78.62%
# Epoch [13/30], Loss: 0.5949, Acc: 79.21%
# Epoch [14/30], Loss: 0.5738, Acc: 79.92%
# Epoch [15/30], Loss: 0.5535, Acc: 80.69%
# Epoch [16/30], Loss: 0.5387, Acc: 81.12%
# Epoch [17/30], Loss: 0.5200, Acc: 81.96%
# Epoch [18/30], Loss: 0.5113, Acc: 82.12%
# Epoch [19/30], Loss: 0.4897, Acc: 82.70%
# Epoch [20/30], Loss: 0.4773, Acc: 83.26%
# Epoch [21/30], Loss: 0.4670, Acc: 83.61%
# Epoch [22/30], Loss: 0.4520, Acc: 84.12%
# Epoch [23/30], Loss: 0.4419, Acc: 84.64%
# Epoch [24/30], Loss: 0.4254, Acc: 84.97%
# Epoch [25/30], Loss: 0.4159, Acc: 85.49%
# Epoch [26/30], Loss: 0.4042, Acc: 85.84%
# Epoch [27/30], Loss: 0.3978, Acc: 85.96%
# Epoch [28/30], Loss: 0.3877, Acc: 86.42%
# Epoch [29/30], Loss: 0.3742, Acc: 86.87%
# Epoch [30/30], Loss: 0.3663, Acc: 87.22%
# Test Accuracy: 81.70%
#
# --- Config: Act=leaky_relu, Init=random, Optim=adam ---
# Epoch [1/30], Loss: 1.3703, Acc: 50.13%
# Epoch [2/30], Loss: 1.0106, Acc: 64.11%
# Epoch [3/30], Loss: 0.8850, Acc: 68.96%
# Epoch [4/30], Loss: 0.7985, Acc: 72.16%
# Epoch [5/30], Loss: 0.7279, Acc: 74.63%
# Epoch [6/30], Loss: 0.6761, Acc: 76.39%
# Epoch [7/30], Loss: 0.6297, Acc: 78.34%
# Epoch [8/30], Loss: 0.5836, Acc: 79.72%
# Epoch [9/30], Loss: 0.5387, Acc: 81.27%
# Epoch [10/30], Loss: 0.5090, Acc: 82.20%
# Epoch [11/30], Loss: 0.4770, Acc: 83.36%
# Epoch [12/30], Loss: 0.4428, Acc: 84.71%
# Epoch [13/30], Loss: 0.4146, Acc: 85.62%
# Epoch [14/30], Loss: 0.3900, Acc: 86.23%
# Epoch [15/30], Loss: 0.3591, Acc: 87.62%
# Epoch [16/30], Loss: 0.3452, Acc: 87.73%
# Epoch [17/30], Loss: 0.3175, Acc: 88.85%
# Epoch [18/30], Loss: 0.3022, Acc: 89.48%
# Epoch [19/30], Loss: 0.2837, Acc: 89.97%
# Epoch [20/30], Loss: 0.2669, Acc: 90.72%
# Epoch [21/30], Loss: 0.2502, Acc: 91.07%
# Epoch [22/30], Loss: 0.2411, Acc: 91.48%
# Epoch [23/30], Loss: 0.2289, Acc: 91.91%
# Epoch [24/30], Loss: 0.2161, Acc: 92.48%
# Epoch [25/30], Loss: 0.2008, Acc: 92.91%
# Epoch [26/30], Loss: 0.1941, Acc: 93.14%
# Epoch [27/30], Loss: 0.1853, Acc: 93.40%
# Epoch [28/30], Loss: 0.1769, Acc: 93.86%
# Epoch [29/30], Loss: 0.1703, Acc: 94.10%
# Epoch [30/30], Loss: 0.1621, Acc: 94.31%
# Test Accuracy: 82.90%
#
# --- Config: Act=leaky_relu, Init=random, Optim=rmsprop ---
# Epoch [1/30], Loss: 1.6577, Acc: 42.30%
# Epoch [2/30], Loss: 1.1508, Acc: 58.99%
# Epoch [3/30], Loss: 0.9477, Acc: 66.86%
# Epoch [4/30], Loss: 0.8321, Acc: 70.96%
# Epoch [5/30], Loss: 0.7494, Acc: 74.17%
# Epoch [6/30], Loss: 0.6672, Acc: 76.89%
# Epoch [7/30], Loss: 0.6149, Acc: 78.52%
# Epoch [8/30], Loss: 0.5608, Acc: 80.48%
# Epoch [9/30], Loss: 0.5173, Acc: 82.02%
# Epoch [10/30], Loss: 0.4752, Acc: 83.46%
# Epoch [11/30], Loss: 0.4418, Acc: 84.65%
# Epoch [12/30], Loss: 0.4139, Acc: 85.55%
# Epoch [13/30], Loss: 0.3834, Acc: 86.70%
# Epoch [14/30], Loss: 0.3557, Acc: 87.69%
# Epoch [15/30], Loss: 0.3341, Acc: 88.25%
# Epoch [16/30], Loss: 0.3163, Acc: 88.97%
# Epoch [17/30], Loss: 0.2975, Acc: 89.66%
# Epoch [18/30], Loss: 0.2808, Acc: 90.11%
# Epoch [19/30], Loss: 0.2696, Acc: 90.69%
# Epoch [20/30], Loss: 0.2483, Acc: 91.27%
# Epoch [21/30], Loss: 0.2419, Acc: 91.58%
# Epoch [22/30], Loss: 0.2282, Acc: 91.96%
# Epoch [23/30], Loss: 0.2239, Acc: 92.14%
# Epoch [24/30], Loss: 0.2099, Acc: 92.74%
# Epoch [25/30], Loss: 0.2054, Acc: 92.95%
# Epoch [26/30], Loss: 0.1910, Acc: 93.29%
# Epoch [27/30], Loss: 0.1862, Acc: 93.48%
# Epoch [28/30], Loss: 0.1820, Acc: 93.69%
# Epoch [29/30], Loss: 0.1746, Acc: 94.04%
# Epoch [30/30], Loss: 0.1738, Acc: 93.88%
# Test Accuracy: 82.50%
#
# Best Custom Configuration: {'act': 'leaky_relu', 'init': 'xavier', 'opt': 'adam'} with Acc: 83.02%

# %%
print("Starting Transfer Learning (ResNet-18)")

# 1. Load Pretrained Model
resnet = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# 2. Freeze parameters (optional, but standard for fine-tuning feature extractors)
# For this lab, we might want to unfreeze to fine-tune everything,
# but let's just modify the final layer as is standard.
for param in resnet.parameters():
    param.requires_grad = False

# 3. Modify the final Fully Connected layer
# ResNet18 input to fc is 512
num_ftrs = resnet.fc.in_features
resnet.fc = nn.Linear(num_ftrs, 10) # 10 classes for CIFAR-10

resnet = resnet.to(device)

# 4. Train ResNet
# We only train the final layer, so it converges fast
optimizer_res = optim.Adam(resnet.fc.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

train_model(resnet, train_loader, criterion, optimizer_res, epochs=30)
resnet_acc = evaluate_model(resnet, test_loader)

print(f"ResNet-18 Accuracy: {resnet_acc:.2f}%")
print(f"Custom CNN Best Accuracy: {best_acc:.2f}%")
# Out:
# Starting Transfer Learning (ResNet-18)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 203MB/s]
# Epoch [1/30], Loss: 1.7274, Acc: 39.51%
# Epoch [2/30], Loss: 1.6023, Acc: 44.17%
# Epoch [3/30], Loss: 1.5883, Acc: 44.67%
# Epoch [4/30], Loss: 1.5800, Acc: 44.88%
# Epoch [5/30], Loss: 1.5759, Acc: 45.36%
# Epoch [6/30], Loss: 1.5675, Acc: 45.45%
# Epoch [7/30], Loss: 1.5718, Acc: 45.32%
# Epoch [8/30], Loss: 1.5699, Acc: 45.63%
# Epoch [9/30], Loss: 1.5614, Acc: 45.69%
# Epoch [10/30], Loss: 1.5695, Acc: 45.44%
# Epoch [11/30], Loss: 1.5709, Acc: 45.25%
# Epoch [12/30], Loss: 1.5626, Acc: 45.42%
# Epoch [13/30], Loss: 1.5667, Acc: 45.70%
# Epoch [14/30], Loss: 1.5726, Acc: 45.26%
# Epoch [15/30], Loss: 1.5616, Acc: 45.74%
# Epoch [16/30], Loss: 1.5668, Acc: 45.38%
# Epoch [17/30], Loss: 1.5668, Acc: 45.62%
# Epoch [18/30], Loss: 1.5675, Acc: 45.82%
# Epoch [19/30], Loss: 1.5675, Acc: 45.24%
# Epoch [20/30], Loss: 1.5683, Acc: 45.51%
# Epoch [21/30], Loss: 1.5685, Acc: 45.60%
# Epoch [22/30], Loss: 1.5684, Acc: 45.45%
# Epoch [23/30], Loss: 1.5649, Acc: 45.62%
# Epoch [24/30], Loss: 1.5693, Acc: 45.61%
# Epoch [25/30], Loss: 1.5613, Acc: 45.74%
# Epoch [26/30], Loss: 1.5597, Acc: 45.93%
# Epoch [27/30], Loss: 1.5668, Acc: 45.44%
# Epoch [28/30], Loss: 1.5720, Acc: 45.39%
# Epoch [29/30], Loss: 1.5646, Acc: 45.67%
# Epoch [30/30], Loss: 1.5685, Acc: 45.59%
# ResNet-18 Accuracy: 45.80%
# Custom CNN Best Accuracy: 83.02%
